# %% [markdown]
# # Understanding feature interactions with SHAP : sklearn's RandomForestRegressor

# %%
import pandas
import sklearn
import scipy
from sklearn import model_selection, linear_model, preprocessing, metrics, ensemble
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import r2_score, classification_report, confusion_matrix, mean_squared_error, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from scipy import cluster
from scipy.cluster import hierarchy
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rxns_df = pandas.read_csv("godineau2023_reactions_with_yields.tsv", sep='\t')
rxns_df_x = rxns_df.drop("Yield of 3aa", axis = 1)
rxns_df_x = rxns_df_x.drop("Conversion of 1a", axis = 1)
rxns_df_y = rxns_df[["Yield of 3aa"]]

# %%
numerical_features = rxns_df_x.select_dtypes(include=['int','float']).columns
categorical_features = rxns_df_x.select_dtypes(include=['object']).columns
label_encoders={}
for feature in categorical_features:
    label_encoders[feature]=LabelEncoder()
    rxns_df_x[feature] = label_encoders[feature].fit_transform(rxns_df_x[feature])
#prepping y
numerical_features_y = rxns_df_y.select_dtypes(include=['int','float']).columns
categorical_features_y = rxns_df_y.select_dtypes(include=['object']).columns
label_encoders_y={}
for feature in categorical_features_y:
    label_encoders[feature]=LabelEncoder()
    rxns_df_y[feature] = label_encoders_y[feature].fit_transform(rxns_df_y[feature])
x_train, x_temp, y_train, y_temp = train_test_split(rxns_df_x, rxns_df_y, test_size=0.3, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5,random_state=42)

# %%
model = RandomForestRegressor(random_state=42)
model.fit(x_train, y_train)
# Out:
# C:\Users\Public.utilisateur\AppData\Local\Temp\ipykernel_9064\1165176309.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x_train, y_train)
# RandomForestRegressor(random_state=42)

# %%
y_train
# Out:
#      Yield of 3aa
# 236         10.83
# 159         85.51
# 146         73.58
# 69           0.41
# 2            0.00
# ..            ...
# 20          10.92
# 188          0.00
# 71          10.77
# 106         34.51
# 102          0.00
#
# [184 rows x 1 columns]

# %%
#validation
y_val_pred = model.predict(x_val)
#accuracy = model.score(y_val_pred, y_val)
accuracy = r2_score(y_val, y_val_pred)
print(f'Validation Accuracy with r2 :{accuracy}')
MAE_val = mean_absolute_error(y_val, y_val_pred)
RMSE_val = np.sqrt(mean_squared_error(y_val, y_val_pred))
print(f"Validation RMSE:{RMSE_val}")
print(f'Validation MAE:{MAE_val}')

#testing
y_test_pred = model.predict(x_test)
accuracy_test = r2_score(y_test, y_test_pred)
#accuracy_test = model.score(y_test_pred, y_test)
print(f'Test Set Accuracy with r2 : {accuracy_test}')
MAE_test = mean_absolute_error(y_test, y_test_pred)
RMSE_test = np.sqrt(mean_squared_error(y_test, y_test_pred))
print(f"Test RMSE:{RMSE_test}")
print(f'Test MAE:{MAE_test}')
# Out:
# Validation Accuracy with r2 :0.5538779963315477
# Validation RMSE:13.65557371711273
# Validation MAE:10.216600000000003
# Test Set Accuracy with r2 : 0.6736592356581093
# Test RMSE:12.303904143888635
# Test MAE:9.722370000000002

# %% [markdown]
# Already we can see that the accuracy here is higher than for the previous models (linear regression, additive model)

# %%
import shap
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
explainer = shap.Explainer(model, x_train)
shap_values = explainer(x_val, check_additivity=False)

# %%
shap.plots.waterfall(shap_values[0], max_display=11)

# %% [markdown]
# Seeing the round have such a big influence makes sense here, it's what we expect with the experiment.

# %%
shap.plots.beeswarm(shap_values)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %% [markdown]
# The two lowest SHAP values are those of the ligand equivalent and BnNH2 equivalent. This is different from both GAM and LR, but qualitatively the information is the same.

# %%
shap.plots.scatter(shap_values[:,"Base"], color=shap_values)

# %% [markdown]
# The most efficient bases are K3PO4 and K2CO3 as expected. K2CO3 seems to work the best with bases like CuBr and CuCl while K3PO4 performs better with Cu(OAc)2.

# %%
shap.plots.scatter(shap_values[:,"Solvent"], color=shap_values)

# %% [markdown]
# DMSO and EtOH lead to the highest yields, again confirmed. DMSO works well with most ligands while EtOH is better with L7, L8, L9...

# %% [markdown]
# ## Analyzing correlated features

# %%
# Compute the correlation matrix
corr = x_train.corr()
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))
# Generate a diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
square=True, linewidths=.5, cbar_kws={"shrink": .5},
annot=True, fmt=".1f")
plt.show()

# %% [markdown]
# All of these correlations are somewhat weak. The highest is between the base equivalent and the temperature, which chemically speaking, was not so expected. An interaction that was expected but isn't here is solvent/solvent equiv.

# %%
correlation_matrix = x_train.corr()
correlation_matrix = np.corrcoef(correlation_matrix)
correlation_matrix = np.abs(correlation_matrix)
dist_matrix = 1 - correlation_matrix
import scipy.cluster.hierarchy as sch
clustering = sch.linkage(dist_matrix, method="complete")
#clustering = shap.utils.hclust(X_train, metric='correlation')
plt.figure(figsize=(10, 7))
plt.title("Dendrograms")
dend = hierarchy.dendrogram(clustering, labels=x_train.columns)
# Rotate labels for better readability
plt.xticks(rotation=90)
# Increase label size for better visibility
plt.tick_params(axis='x', which='major', labelsize=12)
plt.ylabel('Correlation Distance')
plt.show()
# Out:
# scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix

# %% [markdown]
# Most clusters are not very explainable chemistry-wise, but one stands out: ligand and ligand equiv. are forked together ! Solvent and molarity are also relatively close. In the same vein, base and base equiv. are part of the same big cluster, but their interaction is very weak.

# %%
masker = shap.maskers.Partition(x_train, clustering=clustering)
explainer2 = shap.PartitionExplainer(model.predict, masker)
shap_values2 = explainer2(x_val)
# Out:
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  12%|█▎        | 5/40 [00:00<?, ?it/s]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  18%|█▊        | 7/40 [00:12<00:25,  1.32it/s]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  20%|██        | 8/40 [00:13<00:32,  1.02s/it]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  22%|██▎       | 9/40 [00:15<00:35,  1.13s/it]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  25%|██▌       | 10/40 [00:16<00:36,  1.22s/it]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  28%|██▊       | 11/40 [00:17<00:35,  1.23s/it]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  30%|███       | 12/40 [00:19<00:34,  1.22s/it]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  32%|███▎      | 13/40 [00:20<00:32,  1.20s/it]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  35%|███▌      | 14/40 [00:21<00:31,  1.20s/it]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  38%|███▊      | 15/40 [00:22<00:30,  1.23s/it]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  40%|████      | 16/40 [00:24<00:31,  1.31s/it]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  42%|████▎     | 17/40 [00:25<00:30,  1.34s/it]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  45%|████▌     | 18/40 [00:26<00:26,  1.23s/it]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  48%|████▊     | 19/40 [00:27<00:23,  1.13s/it]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  50%|█████     | 20/40 [00:28<00:20,  1.04s/it]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  52%|█████▎    | 21/40 [00:29<00:18,  1.02it/s]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  55%|█████▌    | 22/40 [00:29<00:15,  1.18it/s]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  57%|█████▊    | 23/40 [00:30<00:12,  1.40it/s]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  60%|██████    | 24/40 [00:30<00:09,  1.65it/s]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  62%|██████▎   | 25/40 [00:31<00:12,  1.20it/s]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  65%|██████▌   | 26/40 [00:33<00:13,  1.05it/s]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  68%|██████▊   | 27/40 [00:34<00:14,  1.12s/it]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  70%|███████   | 28/40 [00:35<00:14,  1.19s/it]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  72%|███████▎  | 29/40 [00:37<00:13,  1.24s/it]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  75%|███████▌  | 30/40 [00:38<00:13,  1.33s/it]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  78%|███████▊  | 31/40 [00:40<00:12,  1.43s/it]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  80%|████████  | 32/40 [00:41<00:10,  1.34s/it]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  82%|████████▎ | 33/40 [00:42<00:08,  1.26s/it]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  85%|████████▌ | 34/40 [00:43<00:07,  1.17s/it]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  88%|████████▊ | 35/40 [00:44<00:05,  1.06s/it]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  90%|█████████ | 36/40 [00:44<00:03,  1.11it/s]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  92%|█████████▎| 37/40 [00:45<00:02,  1.30it/s]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  95%|█████████▌| 38/40 [00:45<00:01,  1.50it/s]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer:  98%|█████████▊| 39/40 [00:46<00:00,  1.71it/s]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer: 100%|██████████| 40/40 [00:47<00:00,  1.09it/s]X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# Partition explainer: 41it [00:49,  1.38s/it]

# %% [markdown]
# ??? Still works in the end

# %%
fig = plt.figure(figsize=(6,12))
ax0 = fig.add_subplot(211)
shap.plots.bar(shap_values, max_display=11, show=False)
ax1 = fig.add_subplot(212)
shap.plots.bar(
shap_values2, max_display=11, show=False, clustering_cutoff=0.1
)
plt.tight_layout()
plt.show()

# %% [markdown]
# Very little difference between the two

# %%
shap.plots.bar(shap_values2[0], clustering_cutoff=0.1)

# %% [markdown]
# The correlations are very weak, so it's probably not the best idea to combine these clusters.

# %%
explainer_test = shap.Explainer(model, x_train)
shap_values_test = explainer(x_test, check_additivity=False)

# %%
fig = plt.figure(figsize=(6,12))
ax0 = fig.add_subplot(211)
shap.plots.waterfall(shap_values[1], show=False)
ax1 = fig.add_subplot(212)
shap.plots.waterfall(shap_values_test[1], show=False)
plt.tight_layout()
plt.show()

# %% [markdown]
# Everything makes sense
